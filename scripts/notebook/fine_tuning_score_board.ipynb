# %% [markdown]
# # Fine tuning detection combatants

# %%
from ultralytics import YOLO

# %%
# path_model = "../../models/pretrainned_models/yolo11x.pt"

path_model = "../../models/pretrainned_models/yolo12x.pt"

# %%
# Chargement du modele pré-entrainé
model = YOLO(path_model)

# %%
# Entrainement du modele avec le données labelisées 
path_dataYaml = "../../data/processed/dataset_fine_tuning_incrustation_score_board/data.yaml"
path_model_output = "../../models/fine_tuned_models_score_board"
model_name = "No_name_model" # nom du modele par défaut

# %%
# demande de saisir un nom de model pour l'entrainnement
model_name_temp = input("Entrez le nom du modele : ")
if model_name_temp != "":
    model_name = model_name_temp
    print(f"Nom du modèle : {model_name}")

results = model.train( 
                            data=path_dataYaml, 
                            epochs=150,
                            time=None,
                            patience=15,
                            batch=-1,
                            imgsz=320,
                            save=True,
                            save_period=10,
                            cache="disk",
                            device=0,
                            workers=8,
                            
                            project=path_model_output, 
                            name=model_name,
                            exist_ok=True,
                            pretrained=True,
                            optimizer="auto",
                            seed=0,
                            deterministic=True,
                            single_cls=False,
                            classes=None,
                            rect=False,
                            multi_scale=True,
                            cos_lr=False,
                            close_mosaic=False,
                            resume=False,
                            amp=False,
                            fraction=1.0,
                            profile=True,
                            freeze=False,
                            lr0 = 0.01,
                            lrf = 0.01,
                            momentum=0.937,
                            weight_decay=0.0005,
                            warmup_epochs=3.0,
                            warmup_momentum=0.8,
                            warmup_bias_lr=0.1,
                            box=7.5,
                            cls=0.5,
                            dfl=1.5,
                            pose=12.0,
                            kobj=2.0,
                            nbs=64,
                            overlap_mask=True,
                            mask_ratio=4,
                            dropout=0.0,
                            val=True,
                            plots=True
                            # max_det=10,
                            # iou= 0.7, 
                            # half=False,
                        )
# Out:
# Nom du modèle : y12x_320px_15patience
# New https://pypi.org/project/ultralytics/8.3.105 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.103 🚀 Python-3.10.9 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine/trainer: task=detect, mode=train, model=../../models/pretrainned_models/yolo12x.pt, data=../../data/processed/dataset_fine_tuning_incrustation_score_board/data.yaml, epochs=150, time=None, patience=15, batch=-1, imgsz=320, save=True, save_period=10, cache=disk, device=0, workers=8, project=../../models/fine_tuned_models_score_board, name=y12x_320px_15patience, exist_ok=True, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=False, resume=False, amp=False, fraction=1.0, profile=True, freeze=False, multi_scale=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=2.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=../../models/fine_tuned_models_score_board/y12x_320px_15patience
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  4   9512128  ultralytics.nn.modules.block.A2C2f           [768, 768, 4, True, 4, True, 1.2]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  4   9512128  ultralytics.nn.modules.block.A2C2f           [768, 768, 4, True, 1, True, 1.2]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  2   4727040  ultralytics.nn.modules.block.A2C2f           [1536, 768, 2, False, -1, True, 1.2]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  2   1331328  ultralytics.nn.modules.block.A2C2f           [1536, 384, 2, False, -1, True, 1.2]
#  15                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  2   4579584  ultralytics.nn.modules.block.A2C2f           [1152, 768, 2, False, -1, True, 1.2]
#  18                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  21        [14, 17, 20]  1   3149017  ultralytics.nn.modules.head.Detect           [3, [384, 768, 768]]
# YOLOv12x summary: 488 layers, 59,121,849 parameters, 59,121,833 gradients, 199.8 GFLOPs
#
# Transferred 1239/1245 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Scanning /home/dim/clone_repo/mvt_analyses/data/processed/dataset_fine_tuning_incrustation_score_board/train_set/labels... 65 images, 7 backgrounds, 0 corrupt: 100%|██████████| 65/65 [00:00<00:00, 861.23it/s]
# train: New cache created: /home/dim/clone_repo/mvt_analyses/data/processed/dataset_fine_tuning_incrustation_score_board/train_set/labels.cache
# train: Caching images (0.4GB Disk): 100%|██████████| 65/65 [00:00<00:00, 75751.53it/s]
# AutoBatch: Computing optimal batch size for imgsz=320 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA GeForce RTX 3060) 12.00G total, 2.50G reserved, 1.67G allocated, 7.83G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     59121849       49.96         2.986         95.58         74.22        (1, 3, 320, 320)                    list
#     59121849       99.92         3.708         87.59         89.24        (2, 3, 320, 320)                    list
#     59121849       199.8         4.872         119.6         111.4        (4, 3, 320, 320)                    list
#     59121849       399.7         7.218           159         193.8        (8, 3, 320, 320)                    list
#     59121849       799.3        12.012         309.1         959.8       (16, 3, 320, 320)                    list
# AutoBatch: Using batch-size 3 for CUDA:0 8.72G/12.00G (73%) ✅
# train: Scanning /home/dim/clone_repo/mvt_analyses/data/processed/dataset_fine_tuning_incrustation_score_board/train_set/labels.cache... 65 images, 7 backgrounds, 0 corrupt: 100%|██████████| 65/65 [00:00<?, ?it/s]
# train: Caching images (0.4GB Disk): 100%|██████████| 65/65 [00:00<00:00, 74023.83it/s]
# val: Scanning /home/dim/clone_repo/mvt_analyses/data/processed/dataset_fine_tuning_incrustation_score_board/validation_set/labels... 18 images, 2 backgrounds, 0 corrupt: 100%|██████████| 18/18 [00:00<00:00, 712.24it/s]
# val: New cache created: /home/dim/clone_repo/mvt_analyses/data/processed/dataset_fine_tuning_incrustation_score_board/validation_set/labels.cache
# val: Caching images (0.1GB Disk): 100%|██████████| 18/18 [00:00<00:00, 37154.27it/s]
# Plotting labels to ../../models/fine_tuned_models_score_board/y12x_320px_15patience/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 205 weight(decay=0.0), 214 weight(decay=0.0004921875), 211 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 8 dataloader workers
# Logging results to ../../models/fine_tuned_models_score_board/y12x_320px_15patience
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      4.87G      1.451      2.198      1.239          1        256: 100%|██████████| 22/22 [00:06<00:00,  3.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  8.56it/s]
#                    all         18         16          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/150      10.6G      1.023      0.723     0.9951          4        288: 100%|██████████| 22/22 [00:04<00:00,  4.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.62it/s]
#                    all         18         16     0.0355      0.393      0.263     0.0526
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/150      10.9G     0.8212      0.616          1          2        448: 100%|██████████| 22/22 [00:04<00:00,  4.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.80it/s]
#                    all         18         16     0.0369        0.5      0.268     0.0488
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/150      5.31G     0.9325     0.7068     0.9983          3        160: 100%|██████████| 22/22 [00:04<00:00,  4.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.92it/s]
#                    all         18         16     0.0445       0.75      0.296     0.0693
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/150      5.35G     0.9955     0.8263      1.115          3        416: 100%|██████████| 22/22 [00:04<00:00,  4.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.49it/s]
#                    all         18         16     0.0429       0.75      0.185     0.0681
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/150      5.53G      0.946     0.7813      1.051          4        480: 100%|██████████| 22/22 [00:04<00:00,  4.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.59it/s]
#                    all         18         16     0.0547          1      0.123     0.0725
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/150      5.84G     0.8762     0.6781      1.021          1        256: 100%|██████████| 22/22 [00:04<00:00,  4.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.76it/s]
#                    all         18         16     0.0471       0.75      0.318     0.0927
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/150      6.18G     0.7962     0.5842     0.9926          5        352: 100%|██████████| 22/22 [00:04<00:00,  4.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.74it/s]
#                    all         18         16     0.0502          1      0.185     0.0819
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/150      6.48G     0.9398     0.7688       1.06          3        448: 100%|██████████| 22/22 [00:04<00:00,  4.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.88it/s]
#                    all         18         16     0.0559       0.75     0.0938     0.0584
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/150      6.93G     0.9471      0.707      1.015          4        160: 100%|██████████| 22/22 [00:04<00:00,  4.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.78it/s]
#                    all         18         16     0.0574       0.75     0.0689     0.0505
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/150      7.21G     0.9142     0.6411      1.033          2        160: 100%|██████████| 22/22 [00:04<00:00,  4.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.48it/s]
#                    all         18         16     0.0596      0.964     0.0774     0.0521
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/150      7.55G     0.8348     0.6159     0.9887          6        384: 100%|██████████| 22/22 [00:04<00:00,  4.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.78it/s]
#                    all         18         16      0.055      0.893      0.135     0.0809
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/150      7.89G     0.9188     0.7077      1.066          4        224: 100%|██████████| 22/22 [00:04<00:00,  4.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.66it/s]
#                    all         18         16     0.0702          1      0.314      0.131
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 52, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 67 epochs completed in 0.119 hours.
# Optimizer stripped from ../../models/fine_tuned_models_score_board/y12x_320px_15patience/weights/last.pt, 119.0MB
# Optimizer stripped from ../../models/fine_tuned_models_score_board/y12x_320px_15patience/weights/best.pt, 119.0MB
#
# Validating ../../models/fine_tuned_models_score_board/y12x_320px_15patience/weights/best.pt...
# Ultralytics 8.3.103 🚀 Python-3.10.9 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv12x summary (fused): 283 layers, 59,046,809 parameters, 0 gradients, 198.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.61it/s]
#                    all         18         16      0.177        0.5      0.396       0.17
#          incus_arbitre          2          2      0.353          1      0.695       0.27
#    incrus_presentation         14         14          0          0     0.0961     0.0693
# Speed: 0.2ms preprocess, 20.0ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to ../../models/fine_tuned_models_score_board/y12x_320px_15patience
