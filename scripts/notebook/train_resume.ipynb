# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("../../models/fine_tuned_models/y12x_300_auto_v2/weights/last.pt")  

# Resume training
results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.104 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.103 🚀 Python-3.10.9 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
